# %%
import matplotlib.pyplot as plt
import numpy as np

data_bare1 = [{'00000': 31,
  '00001': 139,
  '10000': 33,
  '10001': 169,
  '10010': 68,
  '10011': 36,
  '10100': 34,
  '10101': 40,
  '10110': 10,
  '10111': 9,
  '11000': 33,
  '11001': 44,
  '11010': 15,
  '11011': 6,
  '11100': 2,
  '11101': 38,
  '11110': 8,
  '11111': 5,
  '00010': 119,
  '00011': 334,
  '00100': 84,
  '00101': 340,
  '00110': 55,
  '00111': 67,
  '01000': 271,
  '01001': 1278,
  '01010': 386,
  '01011': 154,
  '01100': 98,
  '01101': 61,
  '01110': 20,
  '01111': 13},
 {'00000': 25,
  '00001': 114,
  '10000': 33,
  '10001': 187,
  '10010': 78,
  '10011': 28,
  '10100': 44,
  '10101': 57,
  '10110': 6,
  '10111': 15,
  '11000': 54,
  '11001': 54,
  '11010': 8,
  '11011': 12,
  '11100': 9,
  '11101': 20,
  '11110': 7,
  '11111': 5,
  '00010': 65,
  '00011': 250,
  '00100': 88,
  '00101': 383,
  '00110': 66,
  '00111': 26,
  '01000': 250,
  '01001': 1481,
  '01010': 308,
  '01011': 90,
  '01100': 108,
  '01101': 88,
  '01110': 25,
  '01111': 16},
 {'00000': 20,
  '00001': 118,
  '10000': 35,
  '10001': 145,
  '10010': 134,
  '10011': 33,
  '10100': 37,
  '10101': 46,
  '10110': 26,
  '10111': 4,
  '11000': 43,
  '11001': 44,
  '11010': 17,
  '11011': 10,
  '11100': 6,
  '11101': 16,
  '11110': 8,
  '11111': 9,
  '00010': 67,
  '00011': 234,
  '00100': 87,
  '00101': 342,
  '00110': 95,
  '00111': 49,
  '01000': 218,
  '01001': 1287,
  '01010': 547,
  '01011': 108,
  '01100': 99,
  '01101': 72,
  '01110': 28,
  '01111': 16},
 {'00000': 36,
  '00001': 142,
  '10000': 21,
  '10001': 151,
  '10010': 71,
  '10011': 25,
  '10100': 38,
  '10101': 44,
  '10110': 6,
  '10111': 4,
  '11000': 34,
  '11001': 51,
  '11010': 13,
  '11011': 10,
  '11100': 7,
  '11101': 19,
  '11110': 5,
  '11111': 5,
  '00010': 81,
  '00011': 327,
  '00100': 107,
  '00101': 374,
  '00110': 76,
  '00111': 62,
  '01000': 230,
  '01001': 1344,
  '01010': 380,
  '01011': 137,
  '01100': 100,
  '01101': 66,
  '01110': 22,
  '01111': 12},
 {'00000': 29,
  '00001': 102,
  '10000': 27,
  '10001': 158,
  '10010': 77,
  '10011': 35,
  '10100': 41,
  '10101': 48,
  '10110': 8,
  '10111': 12,
  '11000': 43,
  '11001': 34,
  '11010': 22,
  '11011': 4,
  '11100': 10,
  '11101': 13,
  '11110': 4,
  '11111': 6,
  '00010': 81,
  '00011': 254,
  '00100': 86,
  '00101': 352,
  '00110': 69,
  '00111': 64,
  '01000': 260,
  '01001': 1358,
  '01010': 437,
  '01011': 150,
  '01100': 101,
  '01101': 71,
  '01110': 31,
  '01111': 13},
 {'00000': 19,
  '00001': 111,
  '10000': 31,
  '10001': 132,
  '10010': 101,
  '10011': 29,
  '10100': 52,
  '10101': 39,
  '10110': 9,
  '10111': 8,
  '11000': 57,
  '11001': 33,
  '11010': 18,
  '11011': 3,
  '11100': 5,
  '11101': 26,
  '11110': 13,
  '11111': 4,
  '00010': 102,
  '00011': 242,
  '00100': 55,
  '00101': 317,
  '00110': 113,
  '00111': 48,
  '01000': 235,
  '01001': 1331,
  '01010': 533,
  '01011': 91,
  '01100': 101,
  '01101': 91,
  '01110': 35,
  '01111': 16},
 {'00000': 24,
  '00001': 108,
  '10000': 23,
  '10001': 180,
  '10010': 65,
  '10011': 27,
  '10100': 44,
  '10101': 45,
  '10110': 10,
  '10111': 8,
  '11000': 62,
  '11001': 66,
  '11010': 9,
  '11011': 11,
  '11100': 14,
  '11101': 28,
  '11110': 4,
  '11111': 12,
  '00010': 73,
  '00011': 231,
  '00100': 77,
  '00101': 401,
  '00110': 52,
  '00111': 53,
  '01000': 237,
  '01001': 1462,
  '01010': 311,
  '01011': 114,
  '01100': 93,
  '01101': 114,
  '01110': 23,
  '01111': 19},
 {'00000': 26,
  '00001': 119,
  '10000': 39,
  '10001': 160,
  '10010': 102,
  '10011': 22,
  '10100': 44,
  '10101': 34,
  '10110': 22,
  '10111': 9,
  '11000': 47,
  '11001': 41,
  '11010': 21,
  '11011': 8,
  '11100': 8,
  '11101': 21,
  '11110': 13,
  '11111': 2,
  '00010': 102,
  '00011': 239,
  '00100': 76,
  '00101': 319,
  '00110': 70,
  '00111': 50,
  '01000': 234,
  '01001': 1291,
  '01010': 544,
  '01011': 120,
  '01100': 91,
  '01101': 69,
  '01110': 39,
  '01111': 18},
 {'00000': 21,
  '00001': 110,
  '10000': 37,
  '10001': 160,
  '10010': 72,
  '10011': 31,
  '10100': 42,
  '10101': 55,
  '10110': 11,
  '10111': 5,
  '11000': 55,
  '11001': 54,
  '11010': 15,
  '11011': 10,
  '11100': 11,
  '11101': 20,
  '11110': 3,
  '11111': 6,
  '00010': 80,
  '00011': 227,
  '00100': 90,
  '00101': 394,
  '00110': 34,
  '00111': 48,
  '01000': 244,
  '01001': 1546,
  '01010': 309,
  '01011': 113,
  '01100': 92,
  '01101': 71,
  '01110': 23,
  '01111': 11},
 {'00000': 27,
  '00001': 125,
  '10000': 32,
  '10001': 139,
  '10010': 58,
  '10011': 29,
  '10100': 50,
  '10101': 38,
  '10110': 11,
  '10111': 6,
  '11000': 62,
  '11001': 56,
  '11010': 12,
  '11011': 9,
  '11100': 18,
  '11101': 23,
  '11110': 7,
  '11111': 5,
  '00010': 66,
  '00011': 238,
  '00100': 94,
  '00101': 375,
  '00110': 55,
  '00111': 62,
  '01000': 255,
  '01001': 1458,
  '01010': 381,
  '01011': 104,
  '01100': 89,
  '01101': 80,
  '01110': 23,
  '01111': 13},
 {'00000': 41,
  '00001': 129,
  '10000': 20,
  '10001': 167,
  '10010': 67,
  '10011': 34,
  '10100': 49,
  '10101': 53,
  '10110': 14,
  '10111': 9,
  '11000': 42,
  '11001': 47,
  '11010': 13,
  '11011': 4,
  '11100': 7,
  '11101': 24,
  '11110': 9,
  '11111': 8,
  '00010': 80,
  '00011': 261,
  '00100': 103,
  '00101': 424,
  '00110': 49,
  '00111': 68,
  '01000': 237,
  '01001': 1392,
  '01010': 312,
  '01011': 147,
  '01100': 100,
  '01101': 57,
  '01110': 20,
  '01111': 13},
 {'00000': 26,
  '00001': 117,
  '10000': 39,
  '10001': 154,
  '10010': 73,
  '10011': 15,
  '10100': 41,
  '10101': 42,
  '10110': 9,
  '10111': 7,
  '11000': 42,
  '11001': 37,
  '11010': 11,
  '11011': 9,
  '11100': 6,
  '11101': 17,
  '11110': 10,
  '11111': 6,
  '00010': 91,
  '00011': 203,
  '00100': 85,
  '00101': 397,
  '00110': 62,
  '00111': 42,
  '01000': 248,
  '01001': 1448,
  '01010': 415,
  '01011': 107,
  '01100': 123,
  '01101': 76,
  '01110': 29,
  '01111': 13},
 {'00000': 28,
  '00001': 132,
  '10000': 30,
  '10001': 182,
  '10010': 86,
  '10011': 25,
  '10100': 59,
  '10101': 51,
  '10110': 7,
  '10111': 14,
  '11000': 49,
  '11001': 60,
  '11010': 15,
  '11011': 7,
  '11100': 7,
  '11101': 33,
  '11110': 10,
  '11111': 6,
  '00010': 115,
  '00011': 252,
  '00100': 82,
  '00101': 378,
  '00110': 50,
  '00111': 54,
  '01000': 234,
  '01001': 1332,
  '01010': 354,
  '01011': 101,
  '01100': 125,
  '01101': 74,
  '01110': 29,
  '01111': 19},
 {'00000': 31,
  '00001': 144,
  '10000': 41,
  '10001': 162,
  '10010': 78,
  '10011': 35,
  '10100': 36,
  '10101': 44,
  '10110': 20,
  '10111': 12,
  '11000': 30,
  '11001': 51,
  '11010': 9,
  '11011': 12,
  '11100': 9,
  '11101': 21,
  '11110': 5,
  '11111': 1,
  '00010': 95,
  '00011': 336,
  '00100': 75,
  '00101': 428,
  '00110': 58,
  '00111': 51,
  '01000': 235,
  '01001': 1305,
  '01010': 331,
  '01011': 160,
  '01100': 70,
  '01101': 81,
  '01110': 19,
  '01111': 15},
 {'00000': 26,
  '00001': 116,
  '10000': 39,
  '10001': 162,
  '10010': 64,
  '10011': 36,
  '10100': 64,
  '10101': 60,
  '10110': 7,
  '10111': 13,
  '11000': 49,
  '11001': 51,
  '11010': 12,
  '11011': 5,
  '11100': 4,
  '11101': 25,
  '11110': 4,
  '11111': 3,
  '00010': 64,
  '00011': 248,
  '00100': 58,
  '00101': 472,
  '00110': 49,
  '00111': 45,
  '01000': 244,
  '01001': 1419,
  '01010': 322,
  '01011': 105,
  '01100': 96,
  '01101': 98,
  '01110': 19,
  '01111': 21},
 {'00000': 27,
  '00001': 119,
  '10000': 40,
  '10001': 171,
  '10010': 123,
  '10011': 25,
  '10100': 45,
  '10101': 40,
  '10110': 29,
  '10111': 4,
  '11000': 43,
  '11001': 35,
  '11010': 14,
  '11011': 8,
  '11100': 9,
  '11101': 21,
  '11110': 6,
  '11111': 5,
  '00010': 82,
  '00011': 241,
  '00100': 89,
  '00101': 384,
  '00110': 81,
  '00111': 59,
  '01000': 212,
  '01001': 1285,
  '01010': 524,
  '01011': 84,
  '01100': 90,
  '01101': 59,
  '01110': 34,
  '01111': 12},
 {'00000': 30,
  '00001': 100,
  '10000': 30,
  '10001': 111,
  '10010': 93,
  '10011': 36,
  '10100': 61,
  '10101': 35,
  '10110': 19,
  '10111': 12,
  '11000': 68,
  '11001': 47,
  '11010': 22,
  '11011': 4,
  '11100': 8,
  '11101': 15,
  '11110': 13,
  '11111': 5,
  '00010': 100,
  '00011': 199,
  '00100': 93,
  '00101': 356,
  '00110': 84,
  '00111': 80,
  '01000': 256,
  '01001': 1199,
  '01010': 488,
  '01011': 197,
  '01100': 122,
  '01101': 71,
  '01110': 33,
  '01111': 13},
 {'00000': 27,
  '00001': 127,
  '10000': 39,
  '10001': 177,
  '10010': 86,
  '10011': 29,
  '10100': 47,
  '10101': 52,
  '10110': 20,
  '10111': 12,
  '11000': 48,
  '11001': 48,
  '11010': 11,
  '11011': 11,
  '11100': 18,
  '11101': 20,
  '11110': 10,
  '11111': 4,
  '00010': 92,
  '00011': 219,
  '00100': 93,
  '00101': 372,
  '00110': 53,
  '00111': 47,
  '01000': 253,
  '01001': 1392,
  '01010': 370,
  '01011': 112,
  '01100': 107,
  '01101': 68,
  '01110': 28,
  '01111': 8},
 {'00000': 32,
  '00001': 114,
  '10000': 25,
  '10001': 147,
  '10010': 112,
  '10011': 33,
  '10100': 45,
  '10101': 33,
  '10110': 18,
  '10111': 9,
  '11000': 46,
  '11001': 40,
  '11010': 12,
  '11011': 3,
  '11100': 6,
  '11101': 20,
  '11110': 6,
  '11111': 6,
  '00010': 99,
  '00011': 261,
  '00100': 77,
  '00101': 328,
  '00110': 86,
  '00111': 52,
  '01000': 238,
  '01001': 1272,
  '01010': 509,
  '01011': 155,
  '01100': 104,
  '01101': 49,
  '01110': 42,
  '01111': 21},
 {'00000': 26,
  '00001': 132,
  '10000': 35,
  '10001': 187,
  '10010': 85,
  '10011': 19,
  '10100': 47,
  '10101': 49,
  '10110': 20,
  '10111': 10,
  '11000': 50,
  '11001': 59,
  '11010': 16,
  '11011': 15,
  '11100': 8,
  '11101': 25,
  '11110': 8,
  '11111': 6,
  '00010': 84,
  '00011': 225,
  '00100': 96,
  '00101': 355,
  '00110': 63,
  '00111': 49,
  '01000': 211,
  '01001': 1462,
  '01010': 342,
  '01011': 92,
  '01100': 112,
  '01101': 73,
  '01110': 24,
  '01111': 15}]

data_bare2 = [{'00000': 828,
  '00001': 140,
  '10000': 95,
  '10001': 41,
  '10010': 149,
  '10011': 27,
  '10100': 131,
  '10101': 65,
  '10110': 56,
  '10111': 16,
  '11000': 52,
  '11001': 26,
  '11010': 31,
  '11011': 12,
  '11100': 38,
  '11101': 9,
  '11110': 21,
  '11111': 5,
  '00010': 498,
  '00011': 37,
  '00100': 647,
  '00101': 70,
  '00110': 125,
  '00111': 38,
  '01000': 226,
  '01001': 177,
  '01010': 160,
  '01011': 36,
  '01100': 162,
  '01101': 43,
  '01110': 23,
  '01111': 16},
 {'00000': 993,
  '00001': 211,
  '10000': 85,
  '10001': 24,
  '10010': 111,
  '10011': 34,
  '10100': 88,
  '10101': 61,
  '10110': 49,
  '10111': 28,
  '11000': 35,
  '11001': 33,
  '11010': 27,
  '11011': 34,
  '11100': 23,
  '11101': 21,
  '11110': 13,
  '11111': 9,
  '00010': 314,
  '00011': 62,
  '00100': 463,
  '00101': 129,
  '00110': 110,
  '00111': 48,
  '01000': 310,
  '01001': 249,
  '01010': 116,
  '01011': 67,
  '01100': 112,
  '01101': 96,
  '01110': 33,
  '01111': 12},
 {'00000': 757,
  '00001': 179,
  '10000': 57,
  '10001': 46,
  '10010': 152,
  '10011': 38,
  '10100': 141,
  '10101': 69,
  '10110': 63,
  '10111': 6,
  '11000': 83,
  '11001': 43,
  '11010': 22,
  '11011': 16,
  '11100': 42,
  '11101': 29,
  '11110': 14,
  '11111': 4,
  '00010': 481,
  '00011': 70,
  '00100': 564,
  '00101': 69,
  '00110': 133,
  '00111': 38,
  '01000': 357,
  '01001': 179,
  '01010': 125,
  '01011': 29,
  '01100': 114,
  '01101': 44,
  '01110': 31,
  '01111': 5},
 {'00000': 777,
  '00001': 73,
  '10000': 76,
  '10001': 41,
  '10010': 155,
  '10011': 47,
  '10100': 107,
  '10101': 40,
  '10110': 80,
  '10111': 23,
  '11000': 58,
  '11001': 26,
  '11010': 33,
  '11011': 21,
  '11100': 27,
  '11101': 26,
  '11110': 20,
  '11111': 8,
  '00010': 643,
  '00011': 120,
  '00100': 591,
  '00101': 104,
  '00110': 205,
  '00111': 48,
  '01000': 108,
  '01001': 113,
  '01010': 153,
  '01011': 62,
  '01100': 108,
  '01101': 62,
  '01110': 23,
  '01111': 22},
 {'00000': 807,
  '00001': 142,
  '10000': 70,
  '10001': 45,
  '10010': 170,
  '10011': 48,
  '10100': 91,
  '10101': 50,
  '10110': 53,
  '10111': 10,
  '11000': 35,
  '11001': 40,
  '11010': 36,
  '11011': 31,
  '11100': 26,
  '11101': 14,
  '11110': 22,
  '11111': 14,
  '00010': 504,
  '00011': 51,
  '00100': 465,
  '00101': 72,
  '00110': 124,
  '00111': 41,
  '01000': 371,
  '01001': 202,
  '01010': 211,
  '01011': 39,
  '01100': 113,
  '01101': 51,
  '01110': 42,
  '01111': 10},
 {'00000': 815,
  '00001': 93,
  '10000': 81,
  '10001': 21,
  '10010': 133,
  '10011': 43,
  '10100': 125,
  '10101': 50,
  '10110': 38,
  '10111': 17,
  '11000': 37,
  '11001': 34,
  '11010': 31,
  '11011': 29,
  '11100': 31,
  '11101': 20,
  '11110': 16,
  '11111': 13,
  '00010': 394,
  '00011': 63,
  '00100': 690,
  '00101': 103,
  '00110': 89,
  '00111': 22,
  '01000': 328,
  '01001': 242,
  '01010': 107,
  '01011': 55,
  '01100': 146,
  '01101': 88,
  '01110': 27,
  '01111': 19},
 {'00000': 1023,
  '00001': 138,
  '10000': 89,
  '10001': 38,
  '10010': 157,
  '10011': 21,
  '10100': 112,
  '10101': 52,
  '10110': 108,
  '10111': 21,
  '11000': 60,
  '11001': 28,
  '11010': 40,
  '11011': 21,
  '11100': 28,
  '11101': 19,
  '11110': 19,
  '11111': 12,
  '00010': 479,
  '00011': 60,
  '00100': 522,
  '00101': 69,
  '00110': 120,
  '00111': 35,
  '01000': 159,
  '01001': 144,
  '01010': 184,
  '01011': 57,
  '01100': 105,
  '01101': 42,
  '01110': 30,
  '01111': 8},
 {'00000': 855,
  '00001': 201,
  '10000': 60,
  '10001': 37,
  '10010': 111,
  '10011': 16,
  '10100': 93,
  '10101': 57,
  '10110': 56,
  '10111': 14,
  '11000': 23,
  '11001': 33,
  '11010': 36,
  '11011': 15,
  '11100': 23,
  '11101': 20,
  '11110': 30,
  '11111': 8,
  '00010': 460,
  '00011': 39,
  '00100': 572,
  '00101': 82,
  '00110': 126,
  '00111': 42,
  '01000': 202,
  '01001': 236,
  '01010': 242,
  '01011': 46,
  '01100': 163,
  '01101': 62,
  '01110': 30,
  '01111': 10},
 {'00000': 693,
  '00001': 178,
  '10000': 78,
  '10001': 42,
  '10010': 160,
  '10011': 36,
  '10100': 106,
  '10101': 80,
  '10110': 59,
  '10111': 18,
  '11000': 97,
  '11001': 63,
  '11010': 44,
  '11011': 21,
  '11100': 40,
  '11101': 22,
  '11110': 20,
  '11111': 10,
  '00010': 370,
  '00011': 43,
  '00100': 454,
  '00101': 61,
  '00110': 102,
  '00111': 19,
  '01000': 374,
  '01001': 233,
  '01010': 270,
  '01011': 47,
  '01100': 143,
  '01101': 60,
  '01110': 40,
  '01111': 17},
 {'00000': 879,
  '00001': 127,
  '10000': 79,
  '10001': 17,
  '10010': 142,
  '10011': 25,
  '10100': 123,
  '10101': 39,
  '10110': 58,
  '10111': 19,
  '11000': 62,
  '11001': 22,
  '11010': 27,
  '11011': 19,
  '11100': 49,
  '11101': 17,
  '11110': 7,
  '11111': 9,
  '00010': 382,
  '00011': 40,
  '00100': 737,
  '00101': 66,
  '00110': 117,
  '00111': 37,
  '01000': 271,
  '01001': 159,
  '01010': 146,
  '01011': 44,
  '01100': 185,
  '01101': 52,
  '01110': 22,
  '01111': 22},
 {'00000': 1044,
  '00001': 179,
  '10000': 129,
  '10001': 24,
  '10010': 114,
  '10011': 33,
  '10100': 86,
  '10101': 47,
  '10110': 50,
  '10111': 30,
  '11000': 40,
  '11001': 17,
  '11010': 26,
  '11011': 15,
  '11100': 16,
  '11101': 24,
  '11110': 15,
  '11111': 4,
  '00010': 344,
  '00011': 121,
  '00100': 525,
  '00101': 117,
  '00110': 120,
  '00111': 66,
  '01000': 189,
  '01001': 199,
  '01010': 148,
  '01011': 87,
  '01100': 70,
  '01101': 77,
  '01110': 30,
  '01111': 14},
 {'00000': 738,
  '00001': 99,
  '10000': 86,
  '10001': 52,
  '10010': 137,
  '10011': 55,
  '10100': 109,
  '10101': 61,
  '10110': 60,
  '10111': 18,
  '11000': 66,
  '11001': 41,
  '11010': 30,
  '11011': 24,
  '11100': 39,
  '11101': 24,
  '11110': 25,
  '11111': 9,
  '00010': 562,
  '00011': 123,
  '00100': 551,
  '00101': 71,
  '00110': 143,
  '00111': 29,
  '01000': 228,
  '01001': 185,
  '01010': 189,
  '01011': 34,
  '01100': 88,
  '01101': 82,
  '01110': 30,
  '01111': 12},
 {'00000': 958,
  '00001': 236,
  '10000': 81,
  '10001': 33,
  '10010': 104,
  '10011': 42,
  '10100': 73,
  '10101': 55,
  '10110': 51,
  '10111': 21,
  '11000': 28,
  '11001': 27,
  '11010': 18,
  '11011': 28,
  '11100': 18,
  '11101': 18,
  '11110': 17,
  '11111': 10,
  '00010': 314,
  '00011': 76,
  '00100': 457,
  '00101': 143,
  '00110': 117,
  '00111': 64,
  '01000': 302,
  '01001': 263,
  '01010': 123,
  '01011': 87,
  '01100': 118,
  '01101': 86,
  '01110': 19,
  '01111': 13},
 {'00000': 906,
  '00001': 122,
  '10000': 62,
  '10001': 41,
  '10010': 125,
  '10011': 58,
  '10100': 141,
  '10101': 64,
  '10110': 52,
  '10111': 18,
  '11000': 64,
  '11001': 31,
  '11010': 22,
  '11011': 33,
  '11100': 53,
  '11101': 27,
  '11110': 13,
  '11111': 15,
  '00010': 391,
  '00011': 53,
  '00100': 534,
  '00101': 103,
  '00110': 91,
  '00111': 31,
  '01000': 298,
  '01001': 225,
  '01010': 80,
  '01011': 50,
  '01100': 168,
  '01101': 86,
  '01110': 24,
  '01111': 19},
 {'00000': 707,
  '00001': 166,
  '10000': 80,
  '10001': 33,
  '10010': 196,
  '10011': 31,
  '10100': 133,
  '10101': 51,
  '10110': 76,
  '10111': 19,
  '11000': 60,
  '11001': 43,
  '11010': 36,
  '11011': 9,
  '11100': 51,
  '11101': 14,
  '11110': 14,
  '11111': 8,
  '00010': 533,
  '00011': 49,
  '00100': 622,
  '00101': 69,
  '00110': 137,
  '00111': 40,
  '01000': 248,
  '01001': 142,
  '01010': 154,
  '01011': 35,
  '01100': 152,
  '01101': 47,
  '01110': 27,
  '01111': 18},
 {'00000': 814,
  '00001': 217,
  '10000': 61,
  '10001': 42,
  '10010': 130,
  '10011': 15,
  '10100': 78,
  '10101': 53,
  '10110': 59,
  '10111': 11,
  '11000': 29,
  '11001': 45,
  '11010': 39,
  '11011': 17,
  '11100': 26,
  '11101': 26,
  '11110': 17,
  '11111': 8,
  '00010': 434,
  '00011': 30,
  '00100': 614,
  '00101': 70,
  '00110': 130,
  '00111': 29,
  '01000': 216,
  '01001': 217,
  '01010': 237,
  '01011': 48,
  '01100': 180,
  '01101': 61,
  '01110': 41,
  '01111': 6},
 {'00000': 805,
  '00001': 228,
  '10000': 52,
  '10001': 35,
  '10010': 121,
  '10011': 25,
  '10100': 84,
  '10101': 69,
  '10110': 65,
  '10111': 11,
  '11000': 34,
  '11001': 28,
  '11010': 40,
  '11011': 16,
  '11100': 28,
  '11101': 16,
  '11110': 18,
  '11111': 4,
  '00010': 451,
  '00011': 31,
  '00100': 589,
  '00101': 93,
  '00110': 116,
  '00111': 35,
  '01000': 232,
  '01001': 229,
  '01010': 248,
  '01011': 43,
  '01100': 149,
  '01101': 60,
  '01110': 37,
  '01111': 8},
 {'00000': 730,
  '00001': 165,
  '10000': 59,
  '10001': 37,
  '10010': 170,
  '10011': 27,
  '10100': 126,
  '10101': 45,
  '10110': 67,
  '10111': 18,
  '11000': 75,
  '11001': 30,
  '11010': 29,
  '11011': 14,
  '11100': 52,
  '11101': 17,
  '11110': 9,
  '11111': 4,
  '00010': 518,
  '00011': 64,
  '00100': 643,
  '00101': 68,
  '00110': 153,
  '00111': 35,
  '01000': 214,
  '01001': 162,
  '01010': 192,
  '01011': 34,
  '01100': 165,
  '01101': 35,
  '01110': 26,
  '01111': 17},
 {'00000': 708,
  '00001': 92,
  '10000': 67,
  '10001': 43,
  '10010': 121,
  '10011': 38,
  '10100': 99,
  '10101': 49,
  '10110': 88,
  '10111': 14,
  '11000': 59,
  '11001': 32,
  '11010': 19,
  '11011': 11,
  '11100': 22,
  '11101': 24,
  '11110': 21,
  '11111': 5,
  '00010': 610,
  '00011': 167,
  '00100': 554,
  '00101': 89,
  '00110': 161,
  '00111': 52,
  '01000': 218,
  '01001': 185,
  '01010': 215,
  '01011': 43,
  '01100': 72,
  '01101': 77,
  '01110': 30,
  '01111': 15},
 {'00000': 907,
  '00001': 124,
  '10000': 75,
  '10001': 20,
  '10010': 129,
  '10011': 30,
  '10100': 123,
  '10101': 46,
  '10110': 58,
  '10111': 12,
  '11000': 51,
  '11001': 20,
  '11010': 25,
  '11011': 8,
  '11100': 44,
  '11101': 19,
  '11110': 10,
  '11111': 6,
  '00010': 412,
  '00011': 45,
  '00100': 720,
  '00101': 82,
  '00110': 110,
  '00111': 38,
  '01000': 252,
  '01001': 152,
  '01010': 143,
  '01011': 38,
  '01100': 185,
  '01101': 57,
  '01110': 35,
  '01111': 24}]

data_ideal1 = np.array([0.        , 0.        , 0.        , 0.0625    , 0.        ,
       0.1249976 , 0.015625  , 0.        , 0.        , 0.50000455,
       0.140625  , 0.        , 0.03125117, 0.        , 0.        ,
       0.        , 0.        , 0.0625    , 0.03125117, 0.        ,
       0.015625  , 0.        , 0.        , 0.        , 0.015625  ,
       0.        , 0.        , 0.        , 0.        , 0.        ,
       0.        , 0.        ])

data_ideal2 = {'00000': 0.2373053796,
 '00001': 0.0231670469,
 '00010': 0.1350370469,
 '00011': 0.007722793000000002,
 '00100': 0.16879279299999997,
 '00101': 0.018974004999999995,
 '00110': 0.0225058681,
 '00111': 0.0012874353999999999,
 '01000': 0.05692793359999999,
 '01001': 0.056262136099999985,
 '01010': 0.04887313250000001,
 '01011': 0.0100755604,
 '01100': 0.0263672644,
 '01101': 0.015004245800000005,
 '01110': 0.0012874353999999999,
 '01111': 0.00042922450000000014,
 '10000': 0.0115849297,
 '10001': 0.003861396500000001,
 '10010': 0.0450117362,
 '10011': 0.0087890625,
 '10100': 0.030228660899999996,
 '10101': 0.016292122900000008,
 '10110': 0.018753844099999997,
 '10111': 0.0021080797000000004,
 '11000': 0.003861396500000001,
 '11001': 0.007502122899999997,
 '11010': 0.006325433600000002,
 '11011': 0.006250912899999999,
 '11100': 0.002573933300000001,
 '11101': 0.005001559200000002,
 '11110': 0.0008579076999999999,
 '11111': 0.0009765625}

# %%
for i in range(len(data_bare1)):
    for j in data_bare1[i]:
        data_bare1[i][j] = data_bare1[i][j]/4000
for i in range(len(data_bare2)):
    for j in data_bare2[i]:
        data_bare2[i][j] = data_bare2[i][j]/4000
        
print(data_bare1)
print(data_bare2)
# Out:
# [{'00000': 0.00775, '00001': 0.03475, '10000': 0.00825, '10001': 0.04225, '10010': 0.017, '10011': 0.009, '10100': 0.0085, '10101': 0.01, '10110': 0.0025, '10111': 0.00225, '11000': 0.00825, '11001': 0.011, '11010': 0.00375, '11011': 0.0015, '11100': 0.0005, '11101': 0.0095, '11110': 0.002, '11111': 0.00125, '00010': 0.02975, '00011': 0.0835, '00100': 0.021, '00101': 0.085, '00110': 0.01375, '00111': 0.01675, '01000': 0.06775, '01001': 0.3195, '01010': 0.0965, '01011': 0.0385, '01100': 0.0245, '01101': 0.01525, '01110': 0.005, '01111': 0.00325}, {'00000': 0.00625, '00001': 0.0285, '10000': 0.00825, '10001': 0.04675, '10010': 0.0195, '10011': 0.007, '10100': 0.011, '10101': 0.01425, '10110': 0.0015, '10111': 0.00375, '11000': 0.0135, '11001': 0.0135, '11010': 0.002, '11011': 0.003, '11100': 0.00225, '11101': 0.005, '11110': 0.00175, '11111': 0.00125, '00010': 0.01625, '00011': 0.0625, '00100': 0.022, '00101': 0.09575, '00110': 0.0165, '00111': 0.0065, '01000': 0.0625, '01001': 0.37025
# ...

# %%
data_RC1 = dict()
for i in data_bare1[0]:
    data_RC1[i] = 0

summing = [0]*32

for i in range(len(data_bare1)):
    k = 0
    for j in data_bare1[i]:
        summing[k] += data_bare1[i][j] / 20
        k += 1

print(summing)

k = 0
for i in data_RC1:
    data_RC1[i] = summing[k]
    k += 1
    
print(data_RC1)

data_RC2 = dict()
for i in data_bare2[0]:
    data_RC2[i] = 0

summing = [0]*32

for i in range(len(data_bare2)):
    k = 0
    for j in data_bare2[i]:
        summing[k] += data_bare2[i][j] / 20
        k += 1

print(summing)

k = 0
for i in data_RC2:
    data_RC2[i] = summing[k]
    k += 1
    
print(data_RC2)
# Out:
# [0.0069, 0.03022499999999999, 0.008112500000000002, 0.0400125, 0.021162499999999997, 0.007275, 0.0115, 0.0113125, 0.0035249999999999995, 0.0022750000000000005, 0.011962500000000001, 0.011899999999999999, 0.0035625, 0.0020125, 0.0021499999999999996, 0.005562500000000001, 0.0019125000000000004, 0.0013624999999999998, 0.021725, 0.0627625, 0.0211875, 0.0936375, 0.0165, 0.013449999999999998, 0.060024999999999995, 0.341775, 0.1012875, 0.03051249999999999, 0.025262499999999997, 0.018612499999999997, 0.0068249999999999995, 0.0037125]
# ...

# %%
data_RC1 = {'00000': 0.0069, '00001': 0.03022499999999999, '10000': 0.008112500000000002, '10001': 0.0400125, '10010': 0.021162499999999997, '10011': 0.007275, '10100': 0.0115, '10101': 0.0113125, '10110': 0.0035249999999999995, '10111': 0.0022750000000000005, '11000': 0.011962500000000001, '11001': 0.011899999999999999, '11010': 0.0035625, '11011': 0.0020125, '11100': 0.0021499999999999996, '11101': 0.005562500000000001, '11110': 0.0019125000000000004, '11111': 0.0013624999999999998, '00010': 0.021725, '00011': 0.0627625, '00100': 0.0211875, '00101': 0.0936375, '00110': 0.0165, '00111': 0.013449999999999998, '01000': 0.060024999999999995, '01001': 0.341775, '01010': 0.1012875, '01011': 0.03051249999999999, '01100': 0.025262499999999997, '01101': 0.018612499999999997, '01110': 0.0068249999999999995, '01111': 0.0037125}
data_RC2 = {'00000': 0.20929999999999996, '00001': 0.03887500000000001, '10000': 0.019025, '10001': 0.0089, '10010': 0.03483750000000001, '10011': 0.0086125, '10100': 0.0271125, '10101': 0.013787500000000001, '10110': 0.015575, '10111': 0.0043, '11000': 0.013099999999999999, '11001': 0.008275, '11010': 0.0076375, '11011': 0.004925, '11100': 0.00845, '11101': 0.005075, '11110': 0.0042625, '11111': 0.0020624999999999997, '00010': 0.11367499999999998, '00011': 0.016800000000000002, '00100': 0.14392500000000003, '00101': 0.021625, '00110': 0.0316125, '00111': 0.0098375, '01000': 0.0637875, '01001': 0.0486625, '01010': 0.0430375, '01011': 0.0122625, '01100': 0.033725, '01101': 0.01585, '01110': 0.007500000000000001, '01111': 0.0035875}

# %%
def get_prob_dist(data):
    prob_dist = np.zeros(32)
    for i in range(32):
        result = int(bin(i)[2:])
        result = "{:05d}".format(result)
        prob_dist[i] = data[result]
    prob_dist = prob_dist
    return prob_dist

# %%
for n in range(20):
    fig_name = 'exp1_' + str(n+1) + '.png'
    label = ["{:05d}".format(int(bin(i)[2:])) for i in range(32)]
    fig = plt.figure(figsize = (10,5)) 
    plt.bar(np.arange(1,64,2),get_prob_dist(data_RC1), label = 'RC', width = 0.9)
    plt.bar(np.arange(0,64,2), get_prob_dist(data_bare1[n]), label = 'bare', width = 0.9)
    plt.bar(np.arange(0.5,64,2),data_ideal1, label = 'ideal', width = 1.8, fill = False, edgecolor = 'k', linewidth = 1)
    plt.xticks(range(0,64,2),label)
    plt.xticks(rotation = 90)
    plt.ylabel("probability")
    plt.legend()
    #plt.grid()
    #plt.axisbelow(True)
    #fig.patch.set_facecolor('xkcd:mint green')
    #plt.show()
    plt.savefig(fig_name)

# %%
for n in range(20):
    fig_name = 'exp2_' + str(n+1) + '.png'
    label = ["{:05d}".format(int(bin(i)[2:])) for i in range(32)]
    fig = plt.figure(figsize = (10,5)) 
    plt.bar(np.arange(1,64,2),get_prob_dist(data_RC2), label = 'RC')
    plt.bar(np.arange(0,64,2), get_prob_dist(data_bare2[n]), label = 'bare')
    plt.bar(np.arange(0.5,64,2),get_prob_dist(data_ideal2), label = 'ideal', width = 1.6, fill = False, edgecolor = 'k')
    plt.xticks(range(0,64,2),label)
    plt.xticks(rotation = 90)
    plt.ylabel("probability")
    plt.legend()
    #plt.grid()
    #plt.axisbelow(True)
    #fig.patch.set_facecolor('xkcd:mint green')
    #plt.show()
    plt.savefig(fig_name)

# %%
TVD_raw = 0.27527724500000006
TVD_IBU = 0.18142613343572084
TVD_IBU_sym = 0.033154140122295894

# %%
fig_name = 'TVD.png'
label = ['raw', 'IBU','IBU + symmetry']
fig = plt.figure(figsize = (3,2)) 
plt.bar(range(3),[TVD_raw, TVD_IBU, TVD_IBU_sym])
plt.xticks(range(3),label)
plt.ylabel("TVD")
plt.legend()
plt.tight_layout()
#plt.grid()
#plt.axisbelow(True)
#fig.patch.set_facecolor('xkcd:mint green')
#plt.show()
plt.savefig(fig_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
0.033154140122295894

# %%
fig_name = 'exp3.png'
label = ["{:05d}".format(int(bin(i)[2:])) for i in range(32)]
fig = plt.figure(figsize = (10,5)) 
plt.bar(np.arange(1,64,2),get_prob_dist(data_RC2), label = 'RC')
plt.bar(np.arange(0,64,2), get_prob_dist(data_bare2[n]), label = 'bare')
plt.bar(np.arange(0.5,64,2),get_prob_dist(data_ideal2), label = 'ideal', width = 1.6, fill = False, edgecolor = 'k')
plt.xticks(range(0,64,2),label)
plt.xticks(rotation = 90)
plt.ylabel("probability")
plt.legend()
#plt.grid()
#plt.axisbelow(True)
#fig.patch.set_facecolor('xkcd:mint green')
#plt.show()
plt.savefig(fig_name)
